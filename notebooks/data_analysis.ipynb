# %%
# i want to plot rv5_ vs pct_change with df_cl_5m.parquet
# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# %%
# Load data
data_file = '../data/df_cl_5m.parquet'
data = pd.read_parquet(data_file, engine='pyarrow')

# %%
data # 5m close with 38 crypto as columns
# pct_change on daily close
df_pct_change_daily = data.resample('D').last().pct_change().dropna()*100

# %%
df_pct_change_1h = data.resample('1h').last().pct_change().dropna()*100
# Out:
# /var/folders/hf/6mlc3s057f5_b67tc1dw3_7m0000gn/T/ipykernel_34625/256438044.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df_pct_change_1h = data.resample('1h').last().pct_change().dropna()*100

# %%
df_pct_change_daily
# Out:
# symbol                      BTCUSDT   ETHUSDT   BCHUSDT    XRPUSDT   EOSUSDT  \
# Open Time
# 2020-08-23 00:00:00+00:00 -0.141125 -1.122800 -0.620771  -0.384481 -1.218425
# 2020-08-24 00:00:00+00:00  0.852068  4.332481  2.123105   1.263158  1.955475
# 2020-08-25 00:00:00+00:00 -3.625620 -6.086679 -5.233497  -4.123354 -7.848923
# 2020-08-26 00:00:00+00:00  1.227579  0.759573 -0.210313   0.000000 -0.096061
# 2020-08-27 00:00:00+00:00 -1.139783 -0.626911 -3.710029  -4.372967 -4.423077
# ...                             ...       ...       ...        ...       ...
# 2025-01-12 00:00:00+00:00 -0.066200 -0.491797  1.572070  -2.833741 -2.111801
# 2025-01-13 00:00:00+00:00 -0.015450 -3.967296 -4.484645   0.775039 -3.045685
# 2025-01-14 00:00:00+00:00  2.148059  2.801214  2.347604   5.720515  3.795812
# 2025-01-15 00:00:00+00:00  4.087555  7.004054  5.126682  17.785361  9.709962
# 2025-01-16 00:00:00+00:00 -1.367410 -3.327729 -0.282517   6.249403  1.609195
#
# ...

# %%
df_pct_change = data.pct_change().dropna()*100
# Out:
# /var/folders/hf/6mlc3s057f5_b67tc1dw3_7m0000gn/T/ipykernel_34625/1519575406.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df_pct_change = data.pct_change().dropna()*100

# %%
df_pct_change
# Out:
# symbol                      BTCUSDT   ETHUSDT   BCHUSDT   XRPUSDT   EOSUSDT  \
# Open Time
# 2020-08-22 07:05:00+00:00  0.022699 -0.043503 -0.056190  0.321314  0.060938
# 2020-08-22 07:10:00+00:00  0.094587  0.069123  0.084332 -0.035587  0.152253
# 2020-08-22 07:15:00+00:00 -0.159746 -0.324908 -0.049152 -0.249199 -0.304044
# 2020-08-22 07:20:00+00:00  0.144140  0.171967  0.042151  0.107066 -0.091491
# 2020-08-22 07:25:00+00:00  0.126796  0.053808 -0.031600  0.071301  0.122100
# ...                             ...       ...       ...       ...       ...
# 2025-01-16 14:45:00+00:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 2025-01-16 14:50:00+00:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 2025-01-16 14:55:00+00:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 2025-01-16 15:00:00+00:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 2025-01-16 15:05:00+00:00  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...
